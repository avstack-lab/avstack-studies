# %%
import pickle
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load in data

# %%
# load data
ds = ['kitti', 'nuscenes', 'carla']
data = []
for d in ds:
    tab_file = 'study-1-{}-seq-res.p'.format(d)
    with open(tab_file, 'rb') as f:
        data.append(pickle.load(f))
        
# convert to dataframe
df = pd.concat(pd.DataFrame.from_dict(dat) for dat in data)
print(df.shape)
df.head()
# Out:
# (30, 71)
#    Case Dataset  Trial  Metrics_perception_object_3d_tot_TP  \
# 0     0   KITTI      0                                  402
# 1     1   KITTI      0                                  194
# 2     2   KITTI      0                                  402
# 3     3   KITTI      0                                  194
# 4     4   KITTI      0                                  402
#
#    Metrics_perception_object_3d_tot_FP  Metrics_perception_object_3d_tot_FN  \
# 0                                  134                                   44
# 1                                   99                                  252
# 2                                  134                                   44
# 3                                   99                                  252
# 4                                  134                                   44
#
#    Metrics_perception_object_3d_tot_T  \
# 0                                 446
# 1                                 446
# 2                                 446
# 3                                 446
# 4                                 446
#
#    Metrics_perception_object_3d_mean_precision  \
# 0                                     0.762997
# 1                                     0.500200
# 2                                     0.762997
# 3                                     0.500200
# 4                                     0.762997
#
#    Metrics_perception_object_3d_mean_recall  \
# 0                                  0.897040
# 1                                  0.415999
# 2                                  0.897040
# 3                                  0.415999
# 4                                  0.897040
#
#                                                                                                                                                                                                                                                                                                                                                                                         Metrics_tracking_HOTA_HOTA  \
# 0                     [0.6115882159203753, 0.6115882159203753, 0.6115882159203753, 0.6115882159203753, 0.6115882159203753, 0.6115882159203753, 0.6115882159203753, 0.6115882159203753, 0.6115882159203753, 0.6115882159203753, 0.6115882159203753, 0.6115882159203753, 0.6115882159203753, 0.6115882159203753, 0.6115882159203753, 0.6115882159203753, 0.6115882159203753, 0.6115882159203753, 0.6115882159203753]
# 1  [0.40064066411277033, 0.40064066411277033, 0.40064066411277033, 0.40064066411277033, 0.40064066411277033, 0.40064066411277033, 0.40064066411277033, 0.40064066411277033, 0.40064066411277033, 0.40064066411277033, 0.40064066411277033, 0.40064066411277033, 0.40064066411277033, 0.40064066411277033, 0.40064066411277033, 0.40064066411277033, 0.40064066411277033, 0.40064066411277033, 0.40064066411277033]
# 2                     [0.7123721722473952, 0.7123721722473952, 0.7123721722473952, 0.7123721722473952, 0.7123721722473952, 0.7123721722473952, 0.7123721722473952, 0.7123721722473952, 0.7123721722473952, 0.7123721722473952, 0.7123721722473952, 0.7123721722473952, 0.7123721722473952, 0.7123721722473952, 0.7123721722473952, 0.7123721722473952, 0.7123721722473952, 0.7123721722473952, 0.7123721722473952]
# 3  [0.48204490336550637, 0.48204490336550637, 0.48204490336550637, 0.48204490336550637, 0.48204490336550637, 0.48204490336550637, 0.48204490336550637, 0.48204490336550637, 0.48204490336550637, 0.48204490336550637, 0.48204490336550637, 0.48204490336550637, 0.48204490336550637, 0.48204490336550637, 0.48204490336550637, 0.48204490336550637, 0.48204490336550637, 0.48204490336550637, 0.48204490336550637]
# 4                     [0.7003655971382674, 0.7003655971382674, 0.7003655971382674, 0.7003655971382674, 0.7003655971382674, 0.7003655971382674, 0.7003655971382674, 0.7003655971382674, 0.7003655971382674, 0.7003655971382674, 0.7003655971382674, 0.7003655971382674, 0.7003655971382674, 0.7003655971382674, 0.7003655971382674, 0.7003655971382674, 0.7003655971382674, 0.7003655971382674, 0.7003655971382674]
#
#    ... Metrics_prediction_std_ADE Metrics_prediction_std_FDE  \
# 0  ...                   1.037896                   2.196316
# 1  ...                   1.199937                   1.862107
# 2  ...                   0.643589                   1.676179
# 3  ...                   0.609636                   1.207461
# 4  ...                   0.860504                   1.507013
#
#   Metrics_prediction_n_with_truth Metrics_prediction_n_objects  \
# 0                             437                          442
# 1                             286                          286
# 2                             328                          328
# 3                             190                          190
# 4                             298                          298
#
#   Metrics_perception_object_2d_tot_TP Metrics_perception_object_2d_tot_FP  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                               347.0                               224.0
# 3                               347.0                               224.0
# 4                                 0.0                                 0.0
#
#   Metrics_perception_object_2d_tot_FN Metrics_perception_object_2d_tot_T  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                99.0                              446.0
# 3                                99.0                              446.0
# 4                               446.0                              446.0
#
#   Metrics_perception_object_2d_mean_precision  \
# 0                                         NaN
# 1                                         NaN
# 2                                     0.62293
# 3                                     0.62293
# 4                                     0.00000
#
#   Metrics_perception_object_2d_mean_recall
# 0                                      NaN
# 1                                      NaN
# 2                                  0.73162
# 3                                  0.73162
# 4                                  0.00000
#
# [5 rows x 71 columns]

# %% [markdown]
# ## Extract Data of Interest
#
# Rows: case numbers
#
# Columns: metrics
#
# Within columns: each dataset's mean and std values across trials

# %%
metrics_of_interest = {'Metrics_perception_object_3d_mean_precision':'Per: 3D Prec.',
                       'Metrics_perception_object_3d_mean_recall':'Per: 3D Rec.',
                       'Metrics_perception_object_2d_mean_precision':'Per: 2D Prec.',
                       'Metrics_perception_object_2d_mean_recall':'Per: 2D Rec.',
                       'Metrics_tracking_HOTA_HOTA':'Trk: HOTA',
                       'Metrics_tracking_CLEAR_MOTA':'Trk: MOTA',
                       'Metrics_tracking_CLEAR_MOTP':'Trk: MOTP',
                       'Metrics_prediction_std_ADE':'Pred: ADE',
                       'Metrics_prediction_std_FDE':'Pred: FDE'}

expansion_types = {'Metrics_perception_object_3d_mean_precision':None,
                   'Metrics_perception_object_3d_mean_recall':None,
                   'Metrics_perception_object_2d_mean_precision':None,
                   'Metrics_perception_object_2d_mean_recall':None,
                   'Metrics_tracking_HOTA_HOTA':'value-at-middle',
                   'Metrics_tracking_CLEAR_MOTA':'value-at-middle',
                   'Metrics_tracking_CLEAR_MOTP':'value-at-middle',
                   'Metrics_prediction_std_ADE':None,
                   'Metrics_prediction_std_FDE':None}

metric_best_evaluator = {'Metrics_perception_object_3d_mean_precision':np.nanargmax,
                         'Metrics_perception_object_3d_mean_recall':np.nanargmax,
                         'Metrics_perception_object_2d_mean_precision':np.nanargmax,
                         'Metrics_perception_object_2d_mean_recall':np.nanargmax,
                         'Metrics_tracking_HOTA_HOTA':np.nanargmax,
                         'Metrics_tracking_CLEAR_MOTA':np.nanargmax,
                         'Metrics_tracking_CLEAR_MOTP':np.nanargmax,
                         'Metrics_prediction_std_ADE':np.nanargmin,
                         'Metrics_prediction_std_FDE':np.nanargmin}

# %%
# Convert to table format in triple slash format
mark_best_in_cell = True
mask_best_in_col = True

subrow_formatter = '\tworowsubtablecenter{{{}}}{{\tworowsubtablecenter{{{}}}{{{}}}}}'

dses = df["Dataset"].unique()
print(f'Triple slash dataset ordering is: {dses}')
res_triple_agg = []
for i_case in df['Case'].unique():
    res_triple = {'Case':i_case}
    res_triple.update({'Data':subrow_formatter.format(*[d[0].upper() for d in dses])})
    for met_k, met_v in metrics_of_interest.items():
        res_met_triple = []
        for dataset in df['Dataset'].unique():
            met_res = df[(df['Case'] == i_case) & (df['Dataset'] == dataset)][met_k]
            if expansion_types[met_k] == 'max-over-dict':
                met_vals = [np.max(met.values()) for met in met_res]
            elif expansion_types[met_k] == 'max-over-list':
                met_vals = [np.max(met) for met in met_res]
            elif expansion_types[met_k] == 'value-at-middle':
                met_vals = [np.median(met) for met in met_res]  # median accomplishes middle value
            elif expansion_types[met_k] is None:
                met_vals = met_res
            else:
                raise NotImplementedError('Expansion {} not implemented'.format(expansion_types[met_k]))
            mn, std = np.nanmedian(met_vals), np.nanstd(met_vals)
            res_met_triple.append((mn, std))
            
        # triple slash format -- underlining best in cell
        if mark_best_in_cell and (not all([np.isnan(mn) for mn, _ in res_met_triple])):
            best_idx = metric_best_evaluator[met_k]([mn for mn, _ in res_met_triple])
        else:
            best_idx = None
        res_met_triple_new = []
        for i, (mn, std) in enumerate(res_met_triple):
            if np.isnan(mn):
                wstr = 'N/A'
            else:
                if (best_idx is not None) and (i==best_idx):
                    wstr = f'\\underline{{{mn:4.2f} +/- {std:4.2f}}}'
                else:
                    wstr = f'{mn:4.2f} +/- {std:4.2f}'
            res_met_triple_new.append(wstr)

        # Format the whole triple
        res_trip = subrow_formatter.format(*res_met_triple_new)
        res_triple.update({met_v:res_trip})
    res_triple_agg.append(res_triple)
# Out:
# Triple slash dataset ordering is: ['KITTI' 'nuScenes' 'CARLA']
# /home/spencer/.cache/pypoetry/virtualenvs/avstack-studies-CCMTMq_C-py3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# /home/spencer/.cache/pypoetry/virtualenvs/avstack-studies-CCMTMq_C-py3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1878: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,

# %%
pd.set_option('display.max_colwidth',1000)
df_triple = pd.DataFrame(res_triple_agg)
lat_str = df_triple.to_latex(index=False, multirow=True, escape=False).replace('\\\\\n', '\\\\ \\midrule\n')
print(lat_str)
# Out:
# \begin{tabular}{rllllllllll}
# \toprule
#  Case &                                                  Data &                                                                                         Per: 3D Prec. &                                                                                          Per: 3D Rec. &                                                                                         Per: 2D Prec. &                                                                                          Per: 2D Rec. &                                                                                             Trk: HOTA &                                                                                             Trk: MOTA &                                                                                             Trk: MOTP &                                                                                             Pred: ADE &                                                                                             Pred: FDE \\ \midrule
# \midrule
#     0 & \tworowsubtablecenter{K}{\tworowsubtablecenter{N}{C}} & \tworowsubtablecenter{0.57 +/- 0.20}{\tworowsubtablecenter{0.99 +/- 0.01}{\underline{0.99 +/- 0.00}}} & \tworowsubtablecenter{\underline{0.90 +/- 0.00}}{\tworowsubtablecenter{0.25 +/- 0.07}{0.81 +/- 0.00}} &                                           \tworowsubtablecenter{N/A}{\tworowsubtablecenter{N/A}{N/A}} &                                           \tworowsubtablecenter{N/A}{\tworowsubtablecenter{N/A}{N/A}} & \tworowsubtablecenter{0.57 +/- 0.04}{\tworowsubtablecenter{0.11 +/- 0.04}{\underline{0.69 +/- 0.00}}} & \tworowsubtablecenter{0.20 +/- 0.23}{\tworowsubtablecenter{0.20 +/- 0.07}{\underline{0.62 +/- 0.00}}} & \tworowsubtablecenter{\underline{3.66 +/- 0.12}}{\tworowsubtablecenter{2.68 +/- 0.16}{3.11 +/- 0.00}} & \tworowsubtablecenter{1.18 +/- 0.14}{\tworowsubtablecenter{\underline{0.26 +/- 0.08}}{1.04 +/- 0.00}} & \tworowsubtablecenter{3.03 +/- 0.84}{\tworowsubtablecenter{\underline{0.26 +/- 0.08}}{4.10 +/- 0.00}} \\ \midrule
#     1 & \tworowsubtablecenter{K}{\tworowsubtablecenter{N}{C}} & \tworowsubtablecenter{0.37 +/- 0.13}{\tworowsubtablecenter{\underline{1.00 +/- 0.02}}{0.99 +/- 0.00}} & \tworowsubtablecenter{0.40 +/- 0.01}{\tworowsubtablecenter{0.19 +/- 0.06}{\underline{0.68 +/- 0.00}}} &                                           \tworowsubtablecenter{N/A}{\tworowsubtablecenter{N/A}{N/A}} &                                           \tworowsubtablecenter{N/A}{\tworowsubtablecenter{N/A}{N/A}} & \tworowsubtablecenter{0.41 +/- 0.01}{\tworowsubtablecenter{0.09 +/- 0.04}{\underline{0.60 +/- 0.00}}} & \tworowsubtablecenter{0.00 +/- 0.15}{\tworowsubtablecenter{0.12 +/- 0.05}{\underline{0.50 +/- 0.00}}} & \tworowsubtablecenter{\underline{3.10 +/- 0.02}}{\tworowsubtablecenter{2.75 +/- 0.13}{3.06 +/- 0.00}} & \tworowsubtablecenter{1.55 +/- 0.35}{\tworowsubtablecenter{\underline{0.31 +/- 0.06}}{1.17 +/- 0.00}} & \tworowsubtablecenter{3.02 +/- 1.16}{\tworowsubtablecenter{\underline{0.31 +/- 0.06}}{4.49 +/- 0.00}} \\ \midrule
#     2 & \tworowsubtablecenter{K}{\tworowsubtablecenter{N}{C}} & \tworowsubtablecenter{0.57 +/- 0.20}{\tworowsubtablecenter{\underline{0.69 +/- 0.18}}{0.63 +/- 0.00}} & \tworowsubtablecenter{0.90 +/- 0.00}{\tworowsubtablecenter{0.32 +/- 0.02}{\underline{0.95 +/- 0.00}}} & \tworowsubtablecenter{0.46 +/- 0.16}{\tworowsubtablecenter{\underline{0.90 +/- 0.04}}{0.65 +/- 0.00}} & \tworowsubtablecenter{\underline{0.85 +/- 0.12}}{\tworowsubtablecenter{0.52 +/- 0.11}{0.15 +/- 0.00}} & \tworowsubtablecenter{\underline{0.63 +/- 0.09}}{\tworowsubtablecenter{0.11 +/- 0.04}{0.15 +/- 0.00}} & \tworowsubtablecenter{\underline{0.46 +/- 0.14}}{\tworowsubtablecenter{0.11 +/- 0.07}{0.10 +/- 0.00}} & \tworowsubtablecenter{\underline{3.62 +/- 0.18}}{\tworowsubtablecenter{2.89 +/- 0.30}{3.10 +/- 0.00}} & \tworowsubtablecenter{1.26 +/- 0.61}{\tworowsubtablecenter{\underline{1.05 +/- 0.43}}{1.63 +/- 0.00}} & \tworowsubtablecenter{3.33 +/- 1.65}{\tworowsubtablecenter{\underline{1.05 +/- 0.43}}{3.86 +/- 0.00}} \\ \midrule
#     3 & \tworowsubtablecenter{K}{\tworowsubtablecenter{N}{C}} & \tworowsubtablecenter{0.37 +/- 0.13}{\tworowsubtablecenter{\underline{0.67 +/- 0.19}}{0.62 +/- 0.00}} & \tworowsubtablecenter{0.40 +/- 0.01}{\tworowsubtablecenter{0.24 +/- 0.03}{\underline{0.77 +/- 0.00}}} & \tworowsubtablecenter{0.46 +/- 0.16}{\tworowsubtablecenter{\underline{0.90 +/- 0.04}}{0.65 +/- 0.00}} & \tworowsubtablecenter{\underline{0.85 +/- 0.12}}{\tworowsubtablecenter{0.52 +/- 0.11}{0.15 +/- 0.00}} & \tworowsubtablecenter{\underline{0.45 +/- 0.03}}{\tworowsubtablecenter{0.09 +/- 0.03}{0.15 +/- 0.00}} & \tworowsubtablecenter{\underline{0.33 +/- 0.02}}{\tworowsubtablecenter{0.07 +/- 0.03}{0.09 +/- 0.00}} & \tworowsubtablecenter{\underline{3.11 +/- 0.01}}{\tworowsubtablecenter{2.93 +/- 0.29}{3.04 +/- 0.00}} & \tworowsubtablecenter{1.33 +/- 0.72}{\tworowsubtablecenter{\underline{0.63 +/- 0.59}}{1.44 +/- 0.00}} & \tworowsubtablecenter{2.82 +/- 1.61}{\tworowsubtablecenter{\underline{0.63 +/- 0.59}}{3.91 +/- 0.00}} \\ \midrule
#     4 & \tworowsubtablecenter{K}{\tworowsubtablecenter{N}{C}} & \tworowsubtablecenter{0.57 +/- 0.20}{\tworowsubtablecenter{\underline{0.69 +/- 0.18}}{0.63 +/- 0.00}} & \tworowsubtablecenter{0.90 +/- 0.00}{\tworowsubtablecenter{0.32 +/- 0.02}{\underline{0.95 +/- 0.00}}} & \tworowsubtablecenter{\underline{0.00 +/- 0.00}}{\tworowsubtablecenter{0.00 +/- 0.00}{0.00 +/- 0.00}} & \tworowsubtablecenter{\underline{0.00 +/- 0.00}}{\tworowsubtablecenter{0.00 +/- 0.00}{0.00 +/- 0.00}} & \tworowsubtablecenter{\underline{0.64 +/- 0.06}}{\tworowsubtablecenter{0.12 +/- 0.03}{0.51 +/- 0.00}} & \tworowsubtablecenter{\underline{0.51 +/- 0.06}}{\tworowsubtablecenter{0.10 +/- 0.08}{0.50 +/- 0.00}} & \tworowsubtablecenter{\underline{3.68 +/- 0.13}}{\tworowsubtablecenter{2.89 +/- 0.10}{3.16 +/- 0.00}} & \tworowsubtablecenter{1.33 +/- 0.47}{\tworowsubtablecenter{1.06 +/- 0.33}{\underline{0.63 +/- 0.00}}} & \tworowsubtablecenter{2.96 +/- 1.45}{\tworowsubtablecenter{\underline{1.06 +/- 0.33}}{2.58 +/- 0.00}} \\ \midrule
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_1426264/1648327297.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   lat_str = df_triple.to_latex(index=False, multirow=True, escape=False).replace('\\\\\n', '\\\\ \\midrule\n')
